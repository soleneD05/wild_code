# %% [markdown]
# # Preparation

# %% [markdown]
# Install ImageAI.

# %%
# !pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
# !pip install imageai==3.0.3
# Out:
# Collecting imageai==2.0.2
#   Using cached https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl (151 kB)
# Installing collected packages: imageai
#   Attempting uninstall: imageai
#     Found existing installation: imageai 3.0.3
#     Uninstalling imageai-3.0.3:
#       Successfully uninstalled imageai-3.0.3
# Successfully installed imageai-2.0.2
# Collecting imageai==3.0.3
#   Using cached imageai-3.0.3-py3-none-any.whl.metadata (340 bytes)
# Using cached imageai-3.0.3-py3-none-any.whl (69 kB)
# Installing collected packages: imageai
#   Attempting uninstall: imageai
#     Found existing installation: imageai 2.0.2
#     Uninstalling imageai-2.0.2:
#       Successfully uninstalled imageai-2.0.2
# Successfully installed imageai-3.0.3

# %% [markdown]
# Download the weights generated by the ResNet model, trained on the ImageNet dataset.

# %%
from imageai.Classification import ImageClassification
import urllib.request
import os

urllib.request.urlretrieve("https://github.com/OlafenwaMoses/ImageAI/releases/download/3.0.0-pretrained/densenet121-a639ec97.pth","densenet.pth")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# ('densenet.pth', <http.client.HTTPMessage at 0x7e7561c88dd0>)

# %% [markdown]
# Download the picture which we will ateempt to classify using the model.

# %%
urllib.request.urlretrieve('https://upload.wikimedia.org/wikipedia/commons/b/bb/Kittyply_edit1.jpg','cat.jpg')
# Out:
# ('cat.jpg', <http.client.HTTPMessage at 0x7e7561c8b450>)

# %% [markdown]
# # Tasks

# %% [markdown]
# Refer to the ImageAI [documentation](https://imageai.readthedocs.io/en/latest/) to complete the tasks.
#
# *   Create an instance of `ImagePrediction()`.
# *   Since we will be using weights trained on ResNet, set the model type to ResNet.
# *   Set model path to the pre-trained weights you downloaded earlier.
# *   Finally, load the model.

# %%
# Get current execution path
execution_path = os.getcwd()

# Create an instance of ImagePrediction()
prediction = ImageClassification()

# Since we will be using weights trained on ResNet, set the model type to Denseet.
prediction.setModelTypeAsDenseNet121()
prediction.setModelPath(os.path.join(execution_path, "densenet.pth"))
prediction.loadModel()

# %% [markdown]
# Return top 3 predictions and their corresponding probabilities for the image.

# %%
predictions, probabilities = prediction.classifyImage(
    os.path.join(execution_path, "cat.jpg"),
    result_count=3
)

for prediction_label, probability in zip(predictions, probabilities):
    print(prediction_label, ":", probability, "%")
# Out:
# tabby : 59.1719 %
# Egyptian cat : 18.8009 %
# tiger cat : 17.9187 %
